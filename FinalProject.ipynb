# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

# %%
dataset_path = r'C:\Users\Vijay\OneDrive\Documents\Deep_Learning\Project\Final_Project_Dataset\filter'
img_size = (224, 224)
batch_size = 32

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2
)

# %%
train_generator = train_datagen.flow_from_directory(
    dataset_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)
# Out:
# Found 460 images belonging to 5 classes.

# %%
validation_generator = train_datagen.flow_from_directory(
    dataset_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 112 images belonging to 5 classes.

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(256, (3, 3), activation='relu'),  # New Convolutional Layer
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(5, activation='softmax')  # 5 classes: Bicycle, Cat, Dog, female, male
])

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    epochs=2400
)
# Out:
# Epoch 1/2400
# 14/14 [==============================] - 17s 1s/step - loss: 1.6592 - accuracy: 0.2266 - val_loss: 1.5725 - val_accuracy: 0.2188
# Epoch 2/2400
# 14/14 [==============================] - 15s 1s/step - loss: 1.5266 - accuracy: 0.3037 - val_loss: 1.3361 - val_accuracy: 0.4167
# Epoch 3/2400
# 14/14 [==============================] - 15s 1s/step - loss: 1.2872 - accuracy: 0.4416 - val_loss: 1.1578 - val_accuracy: 0.5521
# Epoch 4/2400
# 14/14 [==============================] - 21s 1s/step - loss: 1.2268 - accuracy: 0.4883 - val_loss: 0.9588 - val_accuracy: 0.5729
# Epoch 5/2400
# 14/14 [==============================] - 16s 1s/step - loss: 1.0436 - accuracy: 0.5841 - val_loss: 0.9448 - val_accuracy: 0.6250
# Epoch 6/2400
# 14/14 [==============================] - 15s 1s/step - loss: 0.9544 - accuracy: 0.5958 - val_loss: 0.9245 - val_accuracy: 0.6562
# Epoch 7/2400
# ...

# %%
model.save('object_recognition_model.h5')
# Out:
# C:\Users\Vijay\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
model = tf.keras.models.load_model('object_recognition_model.h5')
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
with open('object_recognition_model.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\Vijay\AppData\Local\Temp\tmpcad5odn8\assets
# INFO:tensorflow:Assets written to: C:\Users\Vijay\AppData\Local\Temp\tmpcad5odn8\assets

# %%
# Plot the training and validation loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Curves')

# Plot the training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Curves')

plt.show()
